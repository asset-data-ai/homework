# %%
import numpy as np
def get_prices_array(products: list):
    print(np.array([p.price for p in products], dtype = float))

product_list = [Product(1, "Laptop", 1200.0, "Electronics"), Product(2, "Mouse", 25.0, "Electronics")]
get_prices_array(product_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 def get_prices_array(products: list):
#       3     print(np.array([p.price for p in products], dtype = float))
# ----> 5 product_list = [Product(1, "Laptop", 1200.0, "Electronics"), Product(2, "Mouse", 25.0, "Electronics")]
#       6 get_prices_array(product_list)
#
# NameError: name 'Product' is not defined
