# %%
#1
def analyze_text(text):
    glasni = "аеиоуыэюя"
    unique_glasni = set()
    not_dyblicat = set()
    words = []
    clean = ""
    text_2 = text + " "
    for i in text_2:
        if i.isalpha():
            clean += i
            if i.lower() in glasni:
                unique_glasni.add(i.lower())
        else:
            if len(clean) > 0:
                if len(clean) >= 5:
                    first_char = clean[0].lower()
                    last_char = clean[-1].lower()
                    if first_char == last_char:
                        w = clean.lower()
                        if w not in not_dyblicat:
                            words.append(w)
                            not_dyblicat.add(w)
            clean = ""
    result = " ".join(words)
    return len(unique_glasni), result


q = "количество уникальных гласных, строка из найденных слов через пробеп"
s = analyze_text(q)
print(f"resalt: {s}")
# Out:
# resalt: (6, 'пробеп')

# %%
#2
def lambdaa(text):
    w = text.split()
    q = []
    e = []
    for i in w:
        if i.isalpha():
            q.append(i)
    for i in q:
        if len(i) % 2 == 0:
            e.append(i[::-1])
    return " ".join(e)

a = "ftrfgi uefg34 ufhv urfhowo"
lambdaa(a)

# lambdaaa = lambda q: " ".join([i[::-1] for i in q.split() if i.isalpha() and len(i) % 2 == 0])
# Out:
# 'igfrtf vhfu'

# %%
#3
def top_k_words(text, k):
    clean = ""
    x = "!\"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"
    for i in text:
        if i in x:
            clean += " "
        else:
            clean += i.lower()
    q = {}
    for i in clean.split():
        if i in q:
            q[i] += 1
        else:
            q[i] = 1
    w = []
    for key, n in q.items():
        w.append((key, n))
    w.sort(key=lambda x: (-x[1], x[0]))
    result = []
    limit = min(k, len(w))
    for i in range(limit):
        result.append(w[i][0])
    return result

a = "apple go to: the apple@ garden next week, go"
s = 3
top_k_words(a, s)
# Out:
# ['apple', 'go', 'garden']

# %%
#4
def www(text):
    q = text.split()
    result = []
    for i in q:
        w = 0
        for j in i:
            if j.isupper():
                w += 1
        if w == 1:
            if not i[0].isupper() and not i[-1].isupper():
                result.append(i)
    return result
a = ("He's ranIng everY dAy ")
www(a)
# Out:
# ['ranIng', 'dAy']

# %%
#5
def compress_text(text):
    result = ""
    count = 1
    first = text[0]
    for i in range(1, len(text)):
        current = text[i]
        if current.lower() == first.lower():
            count += 1
        else:
            result += first
            if count > 1:
                result += str(count)
            first = current
            count = 1
    result += first
    if count > 1:
        result += str(count)
    return result
a = "AaBbCddDee"
compress_text(a)
# Out:
# 'A2B2Cd3e2'

# %%
#6
w = lambda text: [i for i in text.split() if len(i) >= 4 and i.isalpha() and len(set(i.lower())) == len(i.lower())]
a = "World Hello Python test 1234 Data P0P Grey"
print(w(a))
# Out:
# ['World', 'Python', 'Grey']

# %%
#7
def palindrome_words(text):
    clean = ""
    x = "!\"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"
    for i in text:
        if i in x:
            clean += " "
        else:
            clean += i.lower()
    q = set(clean.lower().split())
    palindrome = []
    for i in q:
        if len(i) >= 3 and i == i[::-1]:
            palindrome.append(i)
    palindrome.sort(key=lambda x: (-len(x), x))
    return palindrome
a = "civic level. Racecar! I'm frty. wow, Pop."
palindrome_words(a)
# Out:
# ['racecar', 'civic', 'level', 'pop', 'wow']

# %%
#8
q = lambda text: " ".join([
    i if any(j.isdigit() for j in i) else
    ("VOMEL" if i[0].lower() in "aeiou" else "CONSONANT")
    for i in text.split()
])
a = "Apple banana User123 orange Code 4you"
print(q(a))
# Out:
# VOMEL CONSONANT User123 VOMEL CONSONANT 4you

# %%
#9
def alternate_case_blocks(text, n):
    result = ""
    for i in range(0, len(text), n):
        block = text[i:i+n]
        block_number = i // n
        if block_number % 2 == 0:
            result += block.upper()
        else:
            result += block.lower()
    return result
a = "HelloWorldPython"
s = 3
alternate_case_blocks(a, s)
# Out:
# 'HELlowORLdpyTHOn'

# %%
#10
q = lambda text: len([i for i in text.split()
                      if len(i) >=5
                      and not i[0].isdigit()
                      and any(j.isdigit() for j in i)])
a = "User1 admin 1user agent007 hero 12345 super8"
print(q(a))
# Out:
# 3

# %%
#11
def common_unique_chars(s1, s2):
    s2_1 = set(s2)
    q = set()
    result = []
    for i in s1:
        if (not i.isdigit() and
            not i.isspace() and
            i in s2_1 and
            i not in q):
            result.append(i)
            q.add(i)
    return "".join(result)
w = "Hello World 23"
e = "Old 1 town"
common_unique_chars(w, e)
# Out:
# 'lod'

# %%
#12
q = lambda text: [i for i in text.lower().split() if i[0] == i[-1] and i[::-1] != i and len(i) > 3]
w = "Useru admin 1user agent007 hero 12345 super8"
print(q(w))
# Out:
# ['useru']

# %%
#13
def replace_every_nth(text, n, char):
    result = list(text)
    q = set()
    i = 0
    while i < len(text):
        if text[i].isalpha():
            start = i
            # ИСПРАВЛЕНИЕ 1: Выровняли отступы
            while i < len(text) and text[i].isalpha():
                i += 1
            word_len = i - start
            if word_len < 3:
                for k in range(start, i):
                    q.add(k)
        else:
            i += 1

    for index, symbol in enumerate(result, 1):
        e = index - 1
        if index % n == 0:
            if symbol == " ":
                continue
            if symbol.isdigit():
                continue
            # ИСПРАВЛЕНИЕ 2: Заменили protected_indices на q
            # ИСПРАВЛЕНИЕ 3: Заменили idx_in_list на e
            if e in q:
                continue
            result[e] = char

    return "".join(result)

# --- ТЕСТ ---
text = "Hi world 12345 Python is goood ok"
n_val = 2
char_val = "*"
print(replace_every_nth(text, n_val, char_val))
# Out:
# Hi *o*l* 12345 *y*h*n is *o*o* ok

# %%
#14
q = lambda text: " ".join([i for i in text.split() if len(set(i)) > 3 and all(i.lower().count(j) <= 1 for j in "auiyo")])
w = "Orange Banana Beetle Music Python World"
print(q(w))
# Out:
# Orange Beetle Music Python World

# %%
#15
def word_pattern_sort(text):
    q = text.split()
    def w(e):
        return sum(1 for i in e.lower() if i in "aeiou")
    result = sorted(q, key=lambda e: (len(e), -w(e), e.lower()))
    return result
a = "apple cat onion bee bread idea milk"
word_pattern_sort(a)
# Out:
# ['bee', 'cat', 'idea', 'milk', 'onion', 'apple', 'bread']

# %%
#16
def transform_list(nums):
    q = []
    for i in nums:
        if i < 0:
            continue
        if i % 2 == 0:
            q.append(i ** 2)
        else:
            if i > 10:
                w = sum(int(j) for j in str(i))
                q.append(w)
            else:
                q.append(i)
    return q
a = [-5, 4, 13, 7, 22, 99, -100, 3]
transform_list(a)
# Out:
# [16, 4, 7, 484, 18, 3]

# %%
#17
q = lambda w: [i for i in w if i % 3 == 0 or i % 5 == 0 and i % 15 != 0 and len(str(i)) % 2 == 1]
a = [-5, 4, 13, 7, 22, 99, -100, 3]
print(q(a))
# Out:
# [99, 3]

# %%
#18
def flatten_and_filter(lst):
